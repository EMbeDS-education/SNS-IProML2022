# %% [markdown]
# <center><font size="+4">IProML 2021/2022</font></center>
# <center><font size="+4">Introduction to Programming and</font></center>
# <center><font size="+4">Machine Learning in Python</font></center>
# <center><font size="+4">MODULE 2</font></center>
# <center><font size="+2">Scuola Normale Superiore, Pisa, Italy</font></center>
#
# <center><font size="+2">Course responsibles</font></center>
# <center><font size="+2">Andrea Vandin <a href= "mailto:a.vandin@santannapisa.it">a.vandin@santannapisa.it</a>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Daniele Licari <a href= "mailto:a.vandin@santannapisa.it">d.licari@santannapisa.it</a></font></center>
#
# ---

# %% [markdown]
# <center><font size="+4">Part 1</font></center>
# <center><font size="+4">Lecture 1: Course introduction</font></center>

# %% [markdown]
# ---

# %% [markdown]
# # Course website & material
# All material used in this course, including jupyter notebooks, datasets, schedule are available at the usual wiki
# - https://github.com/EMbeDS-education/SNS-IProML2022/wiki
#
# __This is the second module of IProML__
# - In Module 1 we learned about programming well, python, jupyter-lab
#   - **If you are not familiar with any of these topics: go through the material of Module 1**, available in the above link

# %% [markdown]
# # Course structure
#
# **Part 1: _We first build our toolset_**
# - Topics
#   - Advanced Libraries for data manipulation/visualization
#     - Matplotlib
#     - NumPy
#     - Pandas
#   - Exploratory Data Analysis (EDA) on the Titanic Dataset
#   - Project work if time permits
# - When
#   - Classes 1-3
#
#
# **Part 2, _We apply our toolset on a concrete Machine Learning case study_**
# - Topics
#   - [Breast Cancer Wisconsin (Diagnostic) Data Set](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic))
#     - Exploratory Data Analysis (data pre-processing, outliers detection, ...)
#     - Dimensionality Reduction (PCA)
#     - Clustering (K-means)
#     - Classification (of Benign and Malignant Breast Cancer)
# - When
#   - Classes 4-6
#
#
# **Part 3, _Research-oriented topics_**
# - Topics
#   - [Knime](https://www.knime.com/): a graphical language for complex data analysis tasks
# - When
#   - Class 7

# %%
from IPython.display import Image, display
url_github_repo="https://github.com/EMbeDS-education/SNS-IProML2022/raw/main/"
img=Image(url_github_repo+'slides/figures/scheduleM2.png',width=800)
display(img)

# %% [markdown]
# # Learning objectives
# A student who has met the objectives of the course will be able to:
# - **describe** the main steps and problematics involved in data anlysis and machine learning problems
# - **describe** and **use** advanced Python libraries for data analytics and machine learning
# - **apply** such libraries to medium-complexity problems
# - **describe** modern graphical programming languages for data analysis
# - **describe** the pipeline of steps/problems common in data analysis tasks
# - **communicate** analysis results in a clear and precise manner using popular web-based editors

# %% [markdown]
# # How are we going to evaluate you?
#
# > __IProML does not have a formal examination.__
#
# __How can you evaluate your own learning progress?__
# - The ideal evaluation form for this module would be via an oral examination based on a data analysis/machine learning project
# - In order to improve and better monitor your learning process:
#   - For module 1 we provided you online coding assignments at the end of each class
#   - Here, we provide:
#     - 2 sets of coding assignments
#     - 1 project proposal (actually 2) that you might decide to play with (in a group o 2/3)
#   - Needless to say, we will keep making __kahoot__ quizzes!

# %% [markdown]
# ## Volunteer project 1: Titanic
# - Consider the **Titanic** dataset available in our [dataset folder](https://github.com/EMbeDS-education/StatsAndComputing20212022/wiki/Datasets) with a **description**
#   - Or contact us if you want to propose a dataset of interest.
# - It contains information on 1309 passengers
#   - 14 properties/attributes
#   - 1 target variable on the survival of the passenger
# - __Your task is to analyze this dataset in the lines of what shown in the course__
#   - The final goal is to **obtain a classifier able to predict the survival probability of a hypotethical passenger**
#     - Or other classification tasks to be agreed on if you use a dataset of interest
#   - BEWARE:
#     - Try first to understand the data. Read the provided description.
#     - Not all datasets are the same
#       - Do not just blindly apply all tasks seen in class, with the same parameters.
#       - Try to perform reasoned choices.
#       -  You are free to choose part of the techniques/tools seen during the course
#          - **Motivate your choices**
#     - You should prepare a [jupyterLab notebook](https://jupyterlab.readthedocs.io/en/stable/) containing your analysis
#       - **Properly commenting/motivating each step with suitable comments**
#       - Similarly to what we do in the jupyterLab notebooks we use in our classes

# %% [markdown]
# ## Volunteer project 2: NLP Newsgroups Project
# Alternatively,
# - [The dataset](https://colab.research.google.com/github/EMbeDS-education/SNS-IProML2022/blob/main/jupyter/jupyterNotebooks/M2_NLP_Newsgroups_Project.ipynb) includes 3732 newsgroups posts on 4 topics:
#   - sports
#   - politics
#   - medicine
#   - computer graphics
#
# - It contains
#   - 1 textual data
#   - 1 target variable on the topic
#
# - __Your task is to analyze this dataset in the lines of what shown in the course__
#   - The final goal is to **obtain a classifier able to predict the topic of new posts**

# %% [markdown]
# ---

# %% [markdown]
# # Kahoot

# %% [markdown]
# <!-- ![Last kahoot meme](images/lastKahootMeme.jpg) -->
#
# But now, the most entertaining part this course :D
# - Let's Kahoot!
#
# > A memento from M1... :D

# %%
img=Image(url_github_repo+'jupyter/jupyterNotebooks/images/kahootClass6.JPG',width=800)
display(img)

# %% [markdown]
# How?
# * Using your phone or a different display go to [https://kahoot.it/](https://kahoot.it/)
# * Type the given PIN

# %%
from IPython.display import IFrame
IFrame("https://kahoot.it/", 500, 400)
# Out:
#         <iframe
#             width="500"
#             height="400"
#             src="https://kahoot.it/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
